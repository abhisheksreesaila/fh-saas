# %% [markdown]
# # utils_migrate
#
# > Database migration utilities for PostgreSQL and SQLite with rollback support.
#
# **Note:** This module is maintained directly in `fh_saas/utils_migrate.py` to avoid nbdev export issues.

# %%
#| default_exp utils_migrate

# %% [markdown]
# See [utils_migrate.py](../fh_saas/utils_migrate.py) for the source code.
